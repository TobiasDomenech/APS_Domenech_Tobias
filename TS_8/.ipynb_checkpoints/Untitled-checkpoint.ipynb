# %% [markdown]
# <img src="./logo_UNSAM.jpg" align="right" width="150" />
#
# #### Análisis y Procesamiento de Señales
#
# # Trabajo Práctico Nº8
# ## Filtrado no lineal
# #### Tobías Domenech

# %% [markdown]
# ## Introducción
#
# Hasta ahora sea a trabajado con el desarrollo de filtros lineales de tipo digital para el trabajo de señales y, en particular, se ha manipulado la señal de ECG. Durante este proceso se ha notado la influencia, y exigencia implicita, que impone el ruido de muy baja frecuencia pero que puede aportar grandes cantidades de energía: el movimiento de **línea de base o baseline**.
#
# Hasta este punto, a la hora de elaborar los filtros, los espectros de información y ruido presentes en la señal se consideraban separados. Sin embargo, la práctica a demostrado que este no es así, sino que exite una superposición entre ellos. Ante esta situación es que se implementarán las **técnicas de filtrado no lineal** que tendran por objetivo principal la eliminación del movimiento de línea de base.
#
# En este caso se utilizarán:
#
# - **Filtro de mediana**: Como su nombre lo indica, este tipo de filtro se base en el cálculo del valor estadístico de la mediana (valor central dentro de un conjunto de datos ordenados de menor a mayor; divide en dos la distribución de probabilidad). Esta técnica consistirá en tomar ventanas de datos provenientes de la señal del ECG tal que el cálculo de su mediana sea equivalente a la linea de base. De esta forma, se busca estimar el valor de la linea de base de la señal para luego poder removerse de la señal original (filtrado del ruido de movimiento linea de base). En el caso del ECG se utilizarán dos ventanas: una de 200 ms (para eliminar la "interferencia" que generan los complejos QRS sobre la linea de base que se busca estimar) y luego una de 600 ms (para eliminar la "interferencia" de las otras ondas).
#
# - **Interpolación mediante Splines Cúbicos**: Esta técnica buscará puntos para interpolarlos mediante splines cúbicos estimando, de esta manera, el comportamiento de la línea de base. Para hallar dicho puntos, se buscan aquellos donde, en el caso del ECG, la actividad eléctrica sea nula con tal de que su valor sea lo más cercano a la linea de base posible. En este caso, dichos puntos tienen mayor probabilidad de encontrarse en el segmento PQ, por lo que se tomarán como referencia los datos de la ocurrencia de los distintos latidos y 100 ms previos para caer dentro de estos segmentos. A su vez, en vez de tomarse un único valor de este segmento, se tomará el promedio de 20 muestras para evitar afecciones de otro tipo de interferencias asi como mitigar aquella generada por la red eléctrica de 50 Hz (esta mitigación se debe a que tomando ventanas de 20 muestras = 20 ms, dada la fs de 1000 Hz del ECG, o múltiplos de esta cantidad, se trabaja con multiplos del periodo de la interferencia). Una vez obtenidos los puntos, se interpolan a través de splines cúbicos (garantizando continuidad y suavidad en la curva interpolante) para luego extenderlo a todos los puntos de la señal y obtener la estimación de la linea de base, que posibilita el filtrado de la señal mediante su remosión.
#
# - **Matched Filter**: O filtro adaptado. Esta técnica se fundamentará en la utilización de un patrón que se correlacionará con la señal de interés. En este caso, el patrón de correlación vendrá representado por un latido típico. El fin estará en encontrar aquellos puntos donde la correlación señal-patrón sea máxima (esperando que esto se de en los complejo QRS del ECG) y mínima donde la similitud entra la señal y el patrón sean distintos. Por lo tanto, el método perimitirá estimar dónde ocurren los latidos dentro del ECG (dado que los máximos de correlación deberían darse en los complejos QRS por la "similitud" patron-señal) asi como actuar como filtro dado que el ruido, generalmente no correlado con el patrón, generará mínimos en la correlación y, en consecuencia, su atenuación.
#
# A continuación, se planteará el diseño de las tres técnicas de filtrado no lineal planteadas para trabajar con la señal de ECG. A su vez, se analizará la preformance del Matched Filter en su labor como detector de latidos.

# %% [markdown]
# ### Librerías y Datos comunes

# %%
######################
# FILTRADO NO LINEAL #
######################

import sympy as sp
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt
from pytc2.sistemas_lineales import plot_plantilla
import scipy.io as sio
from scipy.interpolate import CubicSpline
from scipy.signal import find_peaks
import pandas as pd

mat_struct = sio.loadmat('./ECG_TP4.mat')
ecg_one_lead = mat_struct['ecg_lead'].flatten()

ecg_one_lead = ecg_one_lead/np.std(ecg_one_lead) # Normalizo datos ecg

N = len(ecg_one_lead)

fs= 1000 #Hz
nyquist=fs/2

# %% [markdown]
# ### Filtro de Mediana

# %%
#####################
# FILTRO DE MEDIANA #
#####################

window1 = 201  #muestras; como fs = 1000 y tiempo viene en milisegundos => muestras = tiempo
window2 = 601  #muestras; deben ser impares

median_filter = sig.medfilt(ecg_one_lead, kernel_size= window1)
median_filter = sig.medfilt(median_filter, kernel_size= window2)

ecg_filt_mediana = ecg_one_lead - median_filter

## Tomare los datos de 720 a 740 mil muestras para mostrar resultado filtro

zoom_region = np.arange(np.max([0, 12*60*fs]), np.min([N, 12.4*60*fs]), dtype='uint')

datos = ecg_one_lead[zoom_region]


plt.figure(1, figsize=(14, 8))

plt.subplot(3,1,1)
plt.plot(ecg_one_lead, label='ECG', linewidth=1,color='green')
plt.plot(median_filter, label = 'Linea de base', linewidth=1, color='red')
 
plt.title('ECG y su Linea de Base')
plt.ylabel('Amplitud')
plt.legend(loc='lower left')
plt.grid()

plt.subplot(3,1,2)
plt.plot(ecg_one_lead, label='ECG', linewidth=0.5, alpha=0.6 ,color='green')
plt.plot(ecg_filt_mediana, label = 'ECG_filt_mediana', linewidth=0.5, color='red')
 
plt.title('ECG filtrado con mediana')
plt.ylabel('Amplitud')
plt.legend(loc='lower left')
plt.grid()

plt.subplot(3,1,3)
plt.plot(zoom_region, datos, label='ECG', linewidth=1,color='green')
plt.plot(zoom_region, ecg_filt_mediana[zoom_region], label = 'ECG_filt_mediana', linewidth=1, color='red')
 
plt.title('ECG filtrado con mediana')
plt.ylabel('Amplitud')
plt.xlabel('Muestras [#]') 
plt.grid()

plt.legend(loc='lower left')
plt.tight_layout()     
plt.show()

# %% [markdown]
# ### Interpolación mediante Splines Cúbicos

# %%
###################################
# INTERPOLACION X SPLINES CÚBICOS #
###################################

qrs = mat_struct['qrs_detections'].flatten() # Extraigo los valores donde hay latidos


n0 = int(0.1 * fs)  # 100 ms antes del QRS para inicio del segmento PQ
window_length = int(0.02 * fs)  # 20 ms para el segmento de análisis



mi = qrs - n0 # Punto a distancia n0 respecto de latido
s_mi = [] # Valores que tomará señal en punto de interes mi

# Promedio para ventana de 20 ms (20 muestras); permite eliminar interferencia de 50 Hz
for qrs_pos in qrs:
    segment_start = int(qrs_pos - n0)
    segment_end = segment_start + window_length
    
    # Asegurarse que el segmento está dentro del rango
    if segment_start >= 0 and segment_end < N:
        segment = ecg_one_lead[segment_start:segment_end]
        s_mi.append(np.mean(segment))  # Valor promedio del segmento

s_mi = np.array(s_mi)


cs = CubicSpline(mi, s_mi)
baseline_estimate = cs(np.arange(N))  # Evaluar interpolacion en todos los puntos

ecg_filt_s3 = ecg_one_lead - baseline_estimate # Remuevo Linea de Base al ecg (filtro)


plt.figure(2, figsize=(14, 8))


plt.subplot(3, 1, 1)
plt.plot(ecg_one_lead, label='ECG Original', linewidth=1)
plt.plot(baseline_estimate, label = 'Linea de base', linewidth=1, color='orange')
 
plt.title('ECG y su Linea de Base')
plt.ylabel('Amplitud')
plt.legend(loc='lower left')
plt.grid(True)

plt.subplot(3, 1, 2)

plt.plot(ecg_one_lead, 'b', label='ECG Original', alpha=0.5)
plt.plot(ecg_filt_s3, color='orange', label='ECG_filt_s3', linewidth=1)
plt.title('ECG filtrado con Splines3')
plt.ylabel('Amplitud')
plt.legend(loc='lower left')
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(zoom_region, datos, label='ECG', linewidth=1,color='blue')
plt.plot(zoom_region, ecg_filt_s3[zoom_region], label = 'ECG_filt_s3', linewidth=1, color='orange')
 
plt.title('ECG filtrado con Splines3')
plt.ylabel('Amplitud')
plt.xlabel('Muestras [#]') 
plt.legend(loc='lower left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matched Filter

# %%
##################
# MATCHED FILTER #
##################

patron = (mat_struct['qrs_pattern1']).flatten()
patron_norm = (patron - np.mean(patron)) / np.std(patron) # Normalizo patron

ecg = mat_struct['ecg_lead'].flatten()
ecg_norm = (ecg - np.mean(ecg)) / np.std(ecg) # Normalizo ECG

# Correlaciono
correlacion = np.correlate(ecg_norm,patron_norm, mode='same')

# Reescalado para comparación
ecg = ecg_norm / np.max(np.abs(ecg_norm))
correlacion = correlacion / np.max(np.abs(correlacion))

# Busco picos de la señal de correlacion
picos, _ = find_peaks(correlacion, height=0.15 , distance=200 )

plt.figure(3, figsize=(14,8))

plt.subplot(3,1,1)
plt.plot(correlacion,label='Correlacion')
plt.legend(loc='lower left')
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(zoom_region, ecg[zoom_region], label='ECG', linewidth=1,color='blue')
plt.plot(zoom_region, correlacion[zoom_region], label = 'correlacion', linewidth=1, color='orange')
zoom_picos = picos[(picos >= 12*60*fs) & (picos < 12.4*60*fs)]
zoom_qrs = qrs[(qrs >= 12*60*fs) & (qrs < 12.4*60*fs)]
plt.plot(zoom_picos, correlacion[zoom_picos] , 'xr', label = 'picos detectados')
plt.plot(zoom_qrs, ecg[zoom_qrs] , 'xg', label = 'latidos')
 
plt.title('ECG vs correlacion')
plt.ylabel('Amplitud')
plt.legend(loc='lower left')
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(ecg, label='ECG', linewidth=1, alpha = 0.45, color='blue')
plt.plot(correlacion, label = 'correlacion', alpha = 0.65, linewidth=1, color='orange')
plt.plot(picos, correlacion[picos] , 'xr', label = 'picos detectados')

 
plt.title('ECG vs correlacion')
plt.ylabel('Amplitud')
plt.xlabel('Muestras [#]') 
plt.legend(loc='lower left')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Performance Detector de Latidos
#
# En este caso, se eligieron como métricas para la performance a la sensibilidad (o recall) y a la precisión.
#
# $Sensibilidad (Recall): \frac{TP}{(TP + FN)}$ -> capacidad de detectar latidos reales; $TP$ = verdaderos positivos, $FN$ = falsos negativos
#
# $Precisión: \frac{TP}{(TP + FP)}$ -> proporción de detecciones correctas; $FP$ = falsos positivos

# %%
################################
# PERFORMANCE DETECTOR LATIDOS #
################################

# Definir la tolerancia de 100 ms (en muestras)
tolerance_samples = int(0.1 * fs)  # 100 ms

# Inicializar contadores para la tabla de confusión
true_positives = 0
false_positives = 0
false_negatives = 0

# Crear copias de los arrays para no modificar los originales
remaining_detections = qrs.copy()
remaining_peaks = picos.copy()

# Evaluar cada latido real (qrs_detections)
for qrs_pos in qrs:
    # Encontrar picos detectados dentro de la ventana de tolerancia
    matches = remaining_peaks[(remaining_peaks >= qrs_pos - tolerance_samples) & 
                             (remaining_peaks <= qrs_pos + tolerance_samples)]
    
    if len(matches) > 0:
        true_positives += 1
        # Eliminar el pico detectado que ya fue emparejado
        remaining_peaks = remaining_peaks[remaining_peaks != matches[0]]
    else:
        false_negatives += 1

# Los picos restantes son falsos positivos
false_positives = len(remaining_peaks)

# Calcular métricas de performance
sensitivity = true_positives / (true_positives + false_negatives)
precision = true_positives / (true_positives + false_positives)


# Crear DataFrames para mostrar los resultados
confusion_matrix = pd.DataFrame({
    '': ['Predicción Positiva', 'Predicción Negativa'],
    'Real Positivo': [true_positives, false_negatives],
    'Real Negativo': [false_positives, 'N/A']  # No tenemos verdaderos negativos en este caso
})

metrics_df = pd.DataFrame({
    'Métrica': ['Sensibilidad (Recall)', 'Precisión'],
    'Valor': [f"{sensitivity:.4f}", f"{precision:.4f}"],
    'Porcentaje': [f"{sensitivity*100:.2f}%", f"{precision*100:.2f}%"]
})

# Configuración de estilo para las tablas
def style_table(df, title):
    return (df.style
            .set_caption(title)
            .set_properties(**{'text-align': 'center'})
            .hide(axis='index')
            .set_table_styles([
                {'selector': 'caption', 
                 'props': [('font-size', '16px'), 
                          ('font-weight', 'bold'),
                          ('text-align', 'center')]},
                {'selector': 'th', 
                 'props': [('background-color', '#404040'),
                           ('color', 'white'),
                           ('font-weight', 'bold')]},
                {'selector': 'td',
                 'props': [('padding', '8px')]}
            ]))

# Mostrar resultados
print("\n" + "="*50)
print("Performance del Detector de Latidos")
print("="*50)
print(f"\nTolerancia usada: ±{tolerance_samples} muestras (±100 ms)")

# Mostrar tabla de confusión
display(style_table(confusion_matrix, "Tabla de Confusión"))

# Mostrar métricas de performance
display(style_table(metrics_df, "Métricas de Performance"))
# Out:
# ...
# Performance del Detector de Latidos
# ...
#
# Tolerancia usada: ±100 muestras (±100 ms)
# <style type="text/css">
# #T_95c79 caption {
#   font-size: 16px;
#   font-weight: bold;
#   text-align: center;
# }
# #T_95c79 th {
#   background-color: #404040;
#   color: white;
#   font-weight: bold;
# }
# #T_95c79 td {
#   padding: 8px;
# }
# #T_95c79_row0_col0, #T_95c79_row0_col1, #T_95c79_row0_col2, #T_95c79_row1_col0, #T_95c79_row1_col1, #T_95c79_row1_col2 {
#   text-align: center;
# }
# </style>
# <table id="T_95c79">
#   <caption>Tabla de Confusión</caption>
#   <thead>
#     <tr>
#       <th id="T_95c79_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_95c79_level0_col1" class="col_heading level0 col1" >Real Positivo</th>
#       <th id="T_95c79_level0_col2" class="col_heading level0 col2" >Real Negativo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_95c79_row0_col0" class="data row0 col0" >Predicción Positiva</td>
# ...

# %% [markdown]
# ## Resultados y Conclusiones
#
# - En primera instancia, tanto el método de **mediana** como el de **splines cúbicos** muestran su eficiencia para la estimación y remosión del movimiento de linea de base de la señal trabajada aún en situaciones de movimientos abruptos como los latidos ectópicos (cosa que en el filtrado lineal generaba leves afecciones). En cuanto a su implementación, gracias a las funciones provistas por Scipy, el método de la mediana resulta más sencillo.
#
# - Como se estipulaba, el **filtro adaptado** cumple con su labor tanto de filtrado de ruido como de detector de latidos. Presenta como ventaja su sencillez (tanto de implementación, ya que implica simplemente la correlación entre una señal y el patrón, como de citerio de decisión para filtrar dado que se basa en la comparación directa entre señal y patrón), detección de picos basandose simplemente en un criterio de umbral (el cual se puede determinar visualizando el gráfico y estableciendo el valor por sobre el cual la correlación representa un latido). Sin embargo, estas ventajas también pueden tornarse en dificultades en los casos donde el patrón no ajuste correctamente a la señal o la señal sea demasiado cambiante en el tiempo, lo cual podría implicar la oomisión de datos asi como la incorporación de falsos positivos.
#
# - Analizando las métricas del detector de latidos diseñado por el filtro adaptado, se denota una alta sensibilidad y precisión, lo cual quiere decir que detecta la mayoría de los latidos que ocurren (sensibilidad) y no incorpora latidos erroneos (precisión). Por lo tanto, pese a su simpleza, este filtro muestra ser muy bueno en su capacidad de detección de latidos de este ECG.
